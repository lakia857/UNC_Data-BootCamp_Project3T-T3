# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import hvplot.pandas
import folium
from IPython.display import display
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a40ae9ad-581a-48a0-baa0-ea6da9c4dfad" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4e6895ed-aefe-4ae4-a192-3e97d7e59ae0":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"9f774a6a10e443cc9a4040a2573d78b8","client_comm_id":"62ce8af1a7bc4a4bb24b8eee207d8336"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"4e6895ed-aefe-4ae4-a192-3e97d7e59ae0","roots":{"p1002":"a40ae9ad-581a-48a0-baa0-ea6da9c4dfad"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
ev_stations_to_load = Path("Resources/ev_stations_v1.csv")

# %%
ev_stations = pd.read_csv(ev_stations_to_load)
# Out:
# /var/folders/0h/lqy3k6gn3dnf1vwn1ct91kc80000gn/T/ipykernel_11808/2638144155.py:1: DtypeWarning: Columns (6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_stations = pd.read_csv(ev_stations_to_load)

# %%
cleaned_df = ev_stations[["Station Name", "Street Address", "City", "State",
                         "ZIP", "Groups With Access Code", "Access Days Time", 
                         "Latitude", "Longitude", "EV Pricing"]]

# %%
cleaned_df_2 = cleaned_df.dropna(how='any')

# %%
final_charging_df= cleaned_df_2.loc[(cleaned_df_2['EV Pricing'] == 'Free') & 
                                    (cleaned_df_2['Groups With Access Code'] == 'Public')&
                                    (cleaned_df_2['Access Days Time'] == '24 hours daily')]

final_charging_df
# Out:
#                                     Station Name            Street Address  \
# 10                California Air Resources Board          9530 Telstar Ave
# 29                City of Santa Monica - Airport  3223 Donald Douglas Loop
# 33             Van Nuys Amtrak/Metrolink Station        7724 Van Nuys Blvd
# 34                       Office Max - Home Depot       7075 Firestone Blvd
# 48                      Sylmar Metrolink Station            Village Way Dr
# ...                                          ...                       ...
# 49840         Holiday Inn Express Hotel & Suites              2407 Neva Rd
# 49892  Middle Georgia State University - Cochran            1100 SE 2nd St
# 49951                Watchung Municipal Building          15 Mountain Blvd
# 49952                  Gateway Oaks Metro Center      2710 Gateway Oaks Dr
# 50163                   McCulloch County Library         401 E Commerce St
#
#                City State    ZIP Groups With Access Code Access Days Time  \
# 10         El Monte    CA  91731                  Public   24 hours daily
# 29     Santa Monica    CA  90405                  Public   24 hours daily
# 33         Van Nuys    CA  91405                  Public   24 hours daily
# 34           Downey    CA  90241                  Public   24 hours daily
# 48     San Fernando    CA  91342                  Public   24 hours daily
# ...             ...   ...    ...                     ...              ...
# 49840        Antigo    WI  54409                  Public   24 hours daily
# 49892       Cochran    GA  31014                  Public   24 hours daily
# 49951      Watchung    NJ   7069                  Public   24 hours daily
# 49952    Sacramento    CA  95833                  Public   24 hours daily
# 50163         Brady    TX  76825                  Public   24 hours daily
#
#         Latitude   Longitude EV Pricing
# 10     34.068720 -118.064000       Free
# 29     34.017081 -118.447040       Free
# 33     34.211080 -118.448704       Free
# 34     33.947560 -118.153806       Free
# 48     34.292413 -118.449791       Free
# ...          ...         ...        ...
# 49840  45.165529  -89.145651       Free
# 49892  32.380615  -83.346060       Free
# 49951  40.636798  -74.451783       Free
# 49952  38.615468 -121.517263       Free
# 50163  31.134923  -99.331809       Free
#
# [1928 rows x 10 columns]

# %%
final_charging_df.to_csv('Cleaned_data/cleaned_ev_stations.csv', index=False)

# %%
charging_map = folium.Map(location=[39.8,-98.6],tiles='OpenStreetMap', zoom_start=4)

for i in range(0,len(final_charging_df)):
       folium.Marker(
          location=[final_charging_df.iloc[i]['Latitude'], final_charging_df.iloc[i]['Longitude']],
          popup=final_charging_df.iloc[i]['Station Name']).add_to(charging_map)

# for i, row in ev_charging_data.iterrows():
#     Marker(location=[row['Latitude'], row['Longitude']],
#            popup=row['Street Address']).add_to(charging_map)


charging_map.save('charging_map.html') 
display(charging_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f2880894770ea2234cd46ca65fdd588 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f2880894770ea2234cd46ca65fdd588&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f2880894770ea2234cd46ca65fdd588 = L.map(
#                 &quot;map_8f2880894770ea2234cd46ca65fdd588&quot;,
#                 {
#                     center: [39.8, -98.6],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d649e58bbba09b841a0f1544d903b1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1d649e58bbba09b841a0f1544d903b1d.addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#             var marker_4689c3f0c3a893abe42450ea22378223 = L.marker(
#                 [34.06872, -118.064],
#                 {}
#             ).addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#         var popup_ecbf51ed51ab2fb0194d637bab9b8ec6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e4a5a4c01905462956486ab2c4a0c47 = $(`&lt;div id=&quot;html_3e4a5a4c01905462956486ab2c4a0c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California Air Resources Board&lt;/div&gt;`)[0];
#                 popup_ecbf51ed51ab2fb0194d637bab9b8ec6.setContent(html_3e4a5a4c01905462956486ab2c4a0c47);
#
#
#
#         marker_4689c3f0c3a893abe42450ea22378223.bindPopup(popup_ecbf51ed51ab2fb0194d637bab9b8ec6)
#         ;
#
#
#
#
#             var marker_3b68f1aedb48b8b02f05245ce993e7dd = L.marker(
#                 [34.017081, -118.44704],
#                 {}
#             ).addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#         var popup_a14a980b6cdf38fac11f64d5d9f3b775 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccb4f34af74cfe22d9386875a8277eb3 = $(`&lt;div id=&quot;html_ccb4f34af74cfe22d9386875a8277eb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City of Santa Monica - Airport&lt;/div&gt;`)[0];
#                 popup_a14a980b6cdf38fac11f64d5d9f3b775.setContent(html_ccb4f34af74cfe22d9386875a8277eb3);
#
#
#
#         marker_3b68f1aedb48b8b02f05245ce993e7dd.bindPopup(popup_a14a980b6cdf38fac11f64d5d9f3b775)
#         ;
#
#
#
#
#             var marker_bd368be89e8cc4dc6d0541494e3b96a8 = L.marker(
#                 [34.21108, -118.448704],
#                 {}
#             ).addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#         var popup_949135998d505ce084c36edd3b6be7d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_79c46422bb921ebec85cf6db814c2670 = $(`&lt;div id=&quot;html_79c46422bb921ebec85cf6db814c2670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Van Nuys Amtrak/Metrolink Station&lt;/div&gt;`)[0];
#                 popup_949135998d505ce084c36edd3b6be7d7.setContent(html_79c46422bb921ebec85cf6db814c2670);
#
#
#
#         marker_bd368be89e8cc4dc6d0541494e3b96a8.bindPopup(popup_949135998d505ce084c36edd3b6be7d7)
#         ;
#
#
#
#
#             var marker_dcbc5eef4aec3e7bb7555ab18825b833 = L.marker(
#                 [33.94756, -118.153806],
#                 {}
#             ).addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#         var popup_cf663926963e6c652dd395edc7d47793 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d1cf50bf8b803efb48a3d50df918ba5 = $(`&lt;div id=&quot;html_3d1cf50bf8b803efb48a3d50df918ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Office Max - Home Depot&lt;/div&gt;`)[0];
#                 popup_cf663926963e6c652dd395edc7d47793.setContent(html_3d1cf50bf8b803efb48a3d50df918ba5);
#
#
#
#         marker_dcbc5eef4aec3e7bb7555ab18825b833.bindPopup(popup_cf663926963e6c652dd395edc7d47793)
#         ;
#
#
#
#
#             var marker_d3975d34bd34739373d6ce355f64aefd = L.marker(
#                 [34.2924134, -118.4497914],
#                 {}
#             ).addTo(map_8f2880894770ea2234cd46ca65fdd588);
#
#
#         var popup_10784e65d4bd2d4da859fa8295f06733 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a3c1e4284d4251909aeeff8c4148d34 = $(`&lt;div id=&quot;html_9a3c1e4284d4251909aeeff8c4148d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sylmar Metrolink Station&lt;/div&gt;`)[0];
#                 popup_10784e65d4bd2d4da859fa8295f06733.setContent(html_9a3c1e4284d4251909aeeff8c4148d34);
#
#
#
#         marker_d3975d34bd34739373d6ce355f64aefd.bindPopup(popup_10784e65d4bd2d4da859fa8295f06733)
#         ;
#
#
#
#
#             var marker_4fe9236c2910370472b4a583e30864be = L.marker(
#                 [34.145528, -118.050548],

# %%
gas_prices_to_load = Path("Resources/gas_prices.csv")

# %%
gas_prices = pd.read_csv(gas_prices_to_load)
gas_prices.set_index('Year')
# Out:
#         Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# Year
# 2000  1.301  1.369  1.541  1.506  1.498  1.617  1.593  1.510  1.582  1.559
# 2001  1.472  1.484  1.447  1.564  1.729  1.640  1.482  1.427  1.531  1.362
# 2002  1.139  1.130  1.241  1.407  1.421  1.404  1.412  1.423  1.422  1.449
# 2003  1.473  1.641  1.748  1.659  1.542  1.514  1.524  1.628  1.728  1.603
# 2004  1.592  1.672  1.766  1.833  2.009  2.041  1.939  1.898  1.891  2.029
# 2005  1.823  1.918  2.065  2.283  2.216  2.176  2.316  2.506  2.927  2.785
# 2006  2.315  2.310  2.401  2.757  2.947  2.917  2.999  2.985  2.589  2.272
# 2007  2.274  2.285  2.592  2.860  3.130  3.052  2.961  2.782  2.789  2.793
# 2008  3.047  3.033  3.258  3.441  3.764  4.065  4.090  3.786  3.698  3.173
# 2009  1.787  1.928  1.949  2.056  2.265  2.631  2.543  2.627  2.574  2.561
# 2010  2.731  2.659  2.780  2.858  2.869  2.736  2.736  2.745  2.704  2.795
# 2011  3.091  3.167  3.546  3.816  3.933  3.702  3.654  3.630  3.612  3.468
# 2012  3.399  3.572  3.868  3.927  3.792  3.552  3.451  3.707  3.856  3.786
# 2013  3.351  3.693  3.735  3.590  3.623  3.633  3.628  3.600  3.556  3.375
# 2014  3.320  3.364  3.532  3.659  3.691  3.695  3.633  3.481  3.403  3.182
# 2015  2.110  2.249  2.483  2.485  2.775  2.832  2.832  2.679  2.394  2.289
# 2016  1.967  1.767  1.958  2.134  2.264  2.363  2.225  2.155  2.208  2.243
# 2017  2.351  2.299  2.323  2.418  2.386  2.337  2.281  2.374  2.630  2.484
# 2018  2.539  2.575  2.572  2.737  2.907  2.914  2.873  2.862  2.873  2.887
# 2019  2.289  2.353  2.564  2.835  2.901  2.752  2.776  2.655  2.630  2.673
# 2020  2.567  2.465  2.267  1.876  1.879  2.076  2.176  2.177  2.193  2.159
# 2021  2.326  2.496  2.791  2.839  2.972  3.154  3.233  3.255  3.265  3.385
# 2022  3.413  3.592  4.312  4.271  4.604  5.058  4.667  4.101  3.881  4.016
# 2023  3.452  3.514  3.551  3.735  3.685  3.712  3.732  3.955  3.988  3.782
# 2024  3.221  3.359    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         Nov    Dec
# Year
# 2000  1.555  1.489
# 2001  1.263  1.131
# 2002  1.448  1.394
# 2003  1.535  1.494
# 2004  2.010  1.882
# 2005  2.343  2.186
# 2006  2.241  2.334
# 2007  3.069  3.020
# 2008  2.151  1.689
# 2009  2.660  2.621
# 2010  2.852  2.985
# 2011  3.423  3.278
# 2012  3.488  3.331
# 2013  3.251  3.277
# 2014  2.887  2.560
# 2015  2.185  2.060
# 2016  2.187  2.230
# 2017  2.548  2.459
# 2018  2.671  2.414
# 2019  2.620  2.587
# 2020  2.090  2.168
# 2021  3.482  3.408
# 2022  3.853  3.356
# 2023  3.500  3.289
# 2024    NaN    NaN

# %%
gas_prices.plot(x='Year')
plt.ylabel("Gas Prices($)")
plt.title("Monthly changes in gas prices since 2000")
plt.show()
plt.savefig('Images/gas_prices.png')

# %%
ev_sales_to_load = Path("Resources/ev_historical_sales.csv")

# %%
ev_sales = pd.read_csv(ev_sales_to_load)

# %%
ev_sales_cleaned = ev_sales[["region", "powertrain","year", "value"]]

# %%
ev_sales_cleaned.to_csv("Cleaned_data/ev_sales.csv", index=False)

# %%
historical_ev_final = ev_sales_cleaned.loc[(ev_sales_cleaned['region'] == 'USA')].set_index('year')
historical_ev_final
# Out:
#      region powertrain   value
# year
# 2010    USA        BEV    1200
# 2011    USA        BEV    9800
# 2011    USA       PHEV    8000
# 2012    USA       PHEV   39000
# 2012    USA        BEV   15000
# 2013    USA        BEV   48000
# 2013    USA       PHEV   49000
# 2014    USA       PHEV   55000
# 2014    USA        BEV   63000
# 2015    USA        BEV   71000
# 2015    USA       PHEV   43000
# 2016    USA       PHEV   73000
# 2016    USA        BEV   87000
# 2017    USA        BEV  100000
# 2017    USA       PHEV   94000
# 2018    USA       PHEV  120000
# 2018    USA        BEV  240000
# 2019    USA       PHEV   85000
# 2019    USA        BEV  240000
# 2020    USA        BEV  230000
# 2020    USA       PHEV   64000
# 2021    USA       PHEV  160000
# 2021    USA        BEV  470000
# 2022    USA        BEV  800000
# 2022    USA       PHEV  190000

# %%
historical_ev_final.groupby('powertrain')['value'].plot(legend="true")
plt.ylabel('Number of cars sold')
plt.title('BEV vs PHEV cars sold in the USA from 2010 to 2022')
plt.show()
plt.savefig('Images/ev_sales.png')

# %%
sales_compared_to_load = Path("Resources/car_sales_compared.csv")

# %%
all_sales = pd.read_csv(sales_compared_to_load)

# %%
all_sales_final= all_sales.loc[(all_sales['Entity'] == 'United States')]
all_sales_final
# Out:
#             Entity Code  Year  Electric cars sold  Non-electric car sales
# 365  United States  USA  2011               17800              10452788.0
# 366  United States  USA  2012               54000              13116732.0
# 367  United States  USA  2013               97000              13011108.0
# 368  United States  USA  2014              118000              13140427.0
# 369  United States  USA  2015              114000              14501385.0
# 370  United States  USA  2016              160000              15840000.0
# 371  United States  USA  2017              194000              15972666.0
# 372  United States  USA  2018              360000              17640000.0
# 373  United States  USA  2019              325000              15151191.0
# 374  United States  USA  2020              294000              13069636.0
# 375  United States  USA  2021              630000              13370000.0
# 376  United States  USA  2022              990000              11867143.0

# %%
all_sales_final.to_csv('Cleaned_data/all_sales_final.csv', index=False)

# %%
plt.plot(all_sales_final['Year'], all_sales_final['Electric cars sold'], label = 'Electric cars sold')
plt.plot(all_sales_final['Year'], all_sales_final['Non-electric car sales'], label = 'Non-electric cars sold')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Number of cars sold')
plt.title('Car sales in the United States from 2011-2022')
ax= plt.gca()
ax.get_xaxis().get_major_formatter().set_scientific(False)
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()
plt.savefig('Images/all_car_sales.png')
