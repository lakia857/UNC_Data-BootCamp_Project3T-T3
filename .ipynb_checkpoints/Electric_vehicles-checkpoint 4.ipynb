# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import hvplot.pandas
import folium
from IPython.display import display
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c2206f56-f0bb-4e4e-8c5f-ecec03a73cff" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3150e11c-99c6-4642-9636-85f170895b62":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"52b42eef23d74defac939f3f79e667a2","client_comm_id":"fb6c65dc04a64e3ea739dad82a8a4ff9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"3150e11c-99c6-4642-9636-85f170895b62","roots":{"p1002":"c2206f56-f0bb-4e4e-8c5f-ecec03a73cff"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#load ev station csv
ev_stations_to_load = Path("Resources/ev_stations_v1.csv")

# %%
#read csv
ev_stations = pd.read_csv(ev_stations_to_load)
ev_stations
# Out:
# /var/folders/0h/lqy3k6gn3dnf1vwn1ct91kc80000gn/T/ipykernel_17966/1680406485.py:2: DtypeWarning: Columns (6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_stations = pd.read_csv(ev_stations_to_load)
#       Fuel Type Code                       Station Name  \
# 0               ELEC           LADWP - Truesdale Center
# 1               ELEC    LADWP - West LA District Office
# 2               ELEC      Los Angeles Convention Center
# 3               ELEC      LADWP - John Ferraro Building
# 4               ELEC         LADWP - Haynes Power Plant
# ...              ...                                ...
# 50284           ELEC                   VIP LOT STATION1
# 50285           ELEC          Prunedale Shopping Center
# 50286           ELEC          Beaverton Electric Avenue
# 50287           ELEC                      Shell - Inman
# 50288           ELEC  Westfield Trumbull (Trumbull, CT)
#
#                          Street Address   Intersection Directions  \
# 0                    11797 Truesdale St                       NaN
# 1                 1394 S Sepulveda Blvd                       NaN
# 2                    1201 S Figueroa St  West hall and South hall
# 3                         111 N Hope St               Across Hope
# 4                         6801 E 2nd St                       NaN
# ...                                 ...                       ...
# 50284          1501 Kirkwood Meadows Dr                       NaN
# 50285         8065 San Miguel Canyon Rd                       NaN
# 50286  11665 SW Beaverton Hillsdale Hwy                       NaN
# 50287                  2040 Highway 292                       NaN
# 50288                  5065 Main Street                       NaN
#
#                City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0        Sun Valley    CA  91352    NaN           NaN           E  ...
# 1       Los Angeles    CA  90024    NaN           NaN           E  ...
# 2       Los Angeles    CA  90015    NaN  213-741-1151           E  ...
# 3       Los Angeles    CA  90012    NaN           NaN           E  ...
# 4        Long Beach    CA  90803    NaN           NaN           E  ...
# ...             ...   ...    ...    ...           ...         ...  ...
# 50284  Markleeville    CA  96120    NaN  888-758-4389           E  ...
# 50285       Salinas    CA  93907    NaN  877-455-3833           E  ...
# 50286     Beaverton    OR  97005    NaN  855-900-7584           E  ...
# 50287         Inman    SC  29349    NaN  855-900-7584           E  ...
# 50288      Trumbull    CT   6611    NaN  833-632-2778           E  ...
#
#       EV Pricing (French) LPG Nozzle Types Hydrogen Pressures  \
# 0                     NaN              NaN                NaN
# 1                     NaN              NaN                NaN
# 2                     NaN              NaN                NaN
# 3                     NaN              NaN                NaN
# 4                     NaN              NaN                NaN
# ...                   ...              ...                ...
# 50284                 NaN              NaN                NaN
# 50285                 NaN              NaN                NaN
# 50286                 NaN              NaN                NaN
# 50287                 NaN              NaN                NaN
# 50288                 NaN              NaN                NaN
#
#       Hydrogen Standards  CNG Fill Type Code  CNG PSI  CNG Vehicle Class  \
# 0                    NaN                 NaN      NaN                NaN
# 1                    NaN                 NaN      NaN                NaN
# 2                    NaN                 NaN      NaN                NaN
# 3                    NaN                 NaN      NaN                NaN
# 4                    NaN                 NaN      NaN                NaN
# ...                  ...                 ...      ...                ...
# 50284                NaN                 NaN      NaN                NaN
# 50285                NaN                 NaN      NaN                NaN
# 50286                NaN                 NaN      NaN                NaN
# 50287                NaN                 NaN      NaN                NaN
# 50288                NaN                 NaN      NaN                NaN
#
#        LNG Vehicle Class  EV On-Site Renewable Source  Restricted Access
# 0                    NaN                          NaN                NaN
# 1                    NaN                          NaN                NaN
# 2                    NaN                          NaN                NaN
# 3                    NaN                          NaN                NaN
# 4                    NaN                          NaN                NaN
# ...                  ...                          ...                ...
# 50284                NaN                          NaN                NaN
# 50285                NaN                          NaN                NaN
# 50286                NaN                          NaN                NaN
# 50287                NaN                          NaN                NaN
# 50288                NaN                          NaN                NaN
#
# [50289 rows x 65 columns]

# %%
#pull only columns of interest
cleaned_df = ev_stations[["Station Name", "Street Address", "City", "State",
                         "ZIP", "Groups With Access Code", "Access Days Time", 
                         "Latitude", "Longitude", "EV Pricing"]]

# %%
#drop na's
cleaned_df_2 = cleaned_df.dropna(how='any')
cleaned_df_2
# Out:
#                                  Station Name  \
# 10             California Air Resources Board
# 12                     Scripps Green Hospital
# 13                              Galpin Motors
# 14                          Galleria at Tyler
# 15     City of Pasadena - Holly Street Garage
# ...                                       ...
# 50237                        Bill Clough Ford
# 50238        Ford - Jerseyville Motor Company
# 50239                One/Two Irvington Center
# 50240                   600 New Hampshire Ave
# 50241                        Sonesta San Jose
#
#                            Street Address         City State    ZIP  \
# 10                       9530 Telstar Ave     El Monte    CA  91731
# 12                10666 N Torrey Pines Rd     La Jolla    CA  92037
# 13                      15421 Roscoe Blvd    Sepulveda    CA  91343
# 14                 1299 Galleria at Tyler    Riverside    CA  92503
# 15                         150 E Holly St     Pasadena    CA  91103
# ...                                   ...          ...   ...    ...
# 50237                           227 US-13      Windsor    NC  27983
# 50238                     1205 S State St  Jerseyville    IL  62052
# 50239                 702 King Farm Blvd.    Rockville    MD  20850
# 50240  600 New Hampshire Avenue Northwest   Washington    DC  20037
# 50241                    777 Bellew Drive     Milpitas    CA  95035
#
#       Groups With Access Code  \
# 10                     Public
# 12                     Public
# 13        Public - Call ahead
# 14                     Public
# 15                     Public
# ...                       ...
# 50237                  Public
# 50238                  Public
# 50239                  Public
# 50240                  Public
# 50241                  Public
#
#                                         Access Days Time   Latitude  \
# 10                                        24 hours daily  34.068720
# 12                                        24 hours daily  32.899470
# 13                             Dealership business hours  34.221665
# 14                                        6am-12am daily  33.909914
# 15                               24 hours daily; pay lot  34.147620
# ...                                                  ...        ...
# 50237  MON: 24 hours | TUE: 24 hours | WED: 24 hours ...  36.001416
# 50238  MON: 24 hours | TUE: 24 hours | WED: 24 hours ...  39.106184
# 50239  MO: 12:00am-12:00am; TU: 12:00am-12:00am; WE: ...  39.110866
# 50240  MO: Not Specified; TU: Not Specified; WE: Not ...  38.897843
# 50241  MO: Not Specified; TU: Not Specified; WE: Not ...  37.422497
#
#         Longitude                            EV Pricing
# 10    -118.064000                                  Free
# 12    -117.243000                           Pay to Park
# 13    -118.468371                                  Free
# 14    -117.459053                                  Free
# 15    -118.147111                                  Free
# ...           ...                                   ...
# 50237  -76.962169                Level 2: $0.49 per kWh
# 50238  -90.315512                Level 2: $0.49 per kWh
# 50239  -77.177882  $1.00-$10.00/Hr Variable Parking Fee
# 50240  -77.054991                  $2.00/Hr Parking Fee
# 50241 -121.919266                  $0.20/kWh Energy Fee
#
# [14306 rows x 10 columns]

# %%
#filter down to free, public and 24 hours daily
final_charging_df= cleaned_df_2.loc[(cleaned_df_2['EV Pricing'] == 'Free') & 
                                    (cleaned_df_2['Groups With Access Code'] == 'Public')&
                                    (cleaned_df_2['Access Days Time'] == '24 hours daily')]

final_charging_df
# Out:
#                                     Station Name            Street Address  \
# 10                California Air Resources Board          9530 Telstar Ave
# 29                City of Santa Monica - Airport  3223 Donald Douglas Loop
# 33             Van Nuys Amtrak/Metrolink Station        7724 Van Nuys Blvd
# 34                       Office Max - Home Depot       7075 Firestone Blvd
# 48                      Sylmar Metrolink Station            Village Way Dr
# ...                                          ...                       ...
# 49840         Holiday Inn Express Hotel & Suites              2407 Neva Rd
# 49892  Middle Georgia State University - Cochran            1100 SE 2nd St
# 49951                Watchung Municipal Building          15 Mountain Blvd
# 49952                  Gateway Oaks Metro Center      2710 Gateway Oaks Dr
# 50163                   McCulloch County Library         401 E Commerce St
#
#                City State    ZIP Groups With Access Code Access Days Time  \
# 10         El Monte    CA  91731                  Public   24 hours daily
# 29     Santa Monica    CA  90405                  Public   24 hours daily
# 33         Van Nuys    CA  91405                  Public   24 hours daily
# 34           Downey    CA  90241                  Public   24 hours daily
# 48     San Fernando    CA  91342                  Public   24 hours daily
# ...             ...   ...    ...                     ...              ...
# 49840        Antigo    WI  54409                  Public   24 hours daily
# 49892       Cochran    GA  31014                  Public   24 hours daily
# 49951      Watchung    NJ   7069                  Public   24 hours daily
# 49952    Sacramento    CA  95833                  Public   24 hours daily
# 50163         Brady    TX  76825                  Public   24 hours daily
#
#         Latitude   Longitude EV Pricing
# 10     34.068720 -118.064000       Free
# 29     34.017081 -118.447040       Free
# 33     34.211080 -118.448704       Free
# 34     33.947560 -118.153806       Free
# 48     34.292413 -118.449791       Free
# ...          ...         ...        ...
# 49840  45.165529  -89.145651       Free
# 49892  32.380615  -83.346060       Free
# 49951  40.636798  -74.451783       Free
# 49952  38.615468 -121.517263       Free
# 50163  31.134923  -99.331809       Free
#
# [1928 rows x 10 columns]

# %%
#save to new csv
final_charging_df.to_csv('Cleaned_data/cleaned_ev_stations.csv', index=False)

# %%
#use folium to pull in stations of interest and plot on map
charging_map = folium.Map(location=[39.8,-98.6],tiles='OpenStreetMap', zoom_start=4)

for i in range(0,len(final_charging_df)):
       folium.Marker(
          location=[final_charging_df.iloc[i]['Latitude'], final_charging_df.iloc[i]['Longitude']],
          popup=final_charging_df.iloc[i]['Station Name']).add_to(charging_map)

# for i, row in ev_charging_data.iterrows():
#     Marker(location=[row['Latitude'], row['Longitude']],
#            popup=row['Street Address']).add_to(charging_map)


charging_map.save('charging_map.html') 
display(charging_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664d0cc323930b4213b42ba32cf1780d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664d0cc323930b4213b42ba32cf1780d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664d0cc323930b4213b42ba32cf1780d = L.map(
#                 &quot;map_664d0cc323930b4213b42ba32cf1780d&quot;,
#                 {
#                     center: [39.8, -98.6],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03a8bdcc29081fdcb02c798a75675eb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_03a8bdcc29081fdcb02c798a75675eb4.addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#             var marker_c9501c5c833e4fb642b898aed0c2f03e = L.marker(
#                 [34.06872, -118.064],
#                 {}
#             ).addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#         var popup_9782d521ce7679b6adf273b0ecf6b37e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e9e27d5959c0c76188e58d483a05a18 = $(`&lt;div id=&quot;html_3e9e27d5959c0c76188e58d483a05a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California Air Resources Board&lt;/div&gt;`)[0];
#                 popup_9782d521ce7679b6adf273b0ecf6b37e.setContent(html_3e9e27d5959c0c76188e58d483a05a18);
#
#
#
#         marker_c9501c5c833e4fb642b898aed0c2f03e.bindPopup(popup_9782d521ce7679b6adf273b0ecf6b37e)
#         ;
#
#
#
#
#             var marker_8a0f02696e11b44400d4532584ab9b98 = L.marker(
#                 [34.017081, -118.44704],
#                 {}
#             ).addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#         var popup_a756ee6fb5108ed6d411a6c72382a0c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75959658400b4c785e5545214985c171 = $(`&lt;div id=&quot;html_75959658400b4c785e5545214985c171&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City of Santa Monica - Airport&lt;/div&gt;`)[0];
#                 popup_a756ee6fb5108ed6d411a6c72382a0c5.setContent(html_75959658400b4c785e5545214985c171);
#
#
#
#         marker_8a0f02696e11b44400d4532584ab9b98.bindPopup(popup_a756ee6fb5108ed6d411a6c72382a0c5)
#         ;
#
#
#
#
#             var marker_89179b6ac60b652b9b509e9ebabf20b4 = L.marker(
#                 [34.21108, -118.448704],
#                 {}
#             ).addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#         var popup_ff9f54f9baa854868c89da682374d660 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d693183537b2df60b4708d9325bbe865 = $(`&lt;div id=&quot;html_d693183537b2df60b4708d9325bbe865&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Van Nuys Amtrak/Metrolink Station&lt;/div&gt;`)[0];
#                 popup_ff9f54f9baa854868c89da682374d660.setContent(html_d693183537b2df60b4708d9325bbe865);
#
#
#
#         marker_89179b6ac60b652b9b509e9ebabf20b4.bindPopup(popup_ff9f54f9baa854868c89da682374d660)
#         ;
#
#
#
#
#             var marker_f2afa696ed43b269299c52b40d59bd52 = L.marker(
#                 [33.94756, -118.153806],
#                 {}
#             ).addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#         var popup_d3fb7f635264c00c8b9b65042947f2c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8802a22f68f48fee4dd0fc5c4b22d384 = $(`&lt;div id=&quot;html_8802a22f68f48fee4dd0fc5c4b22d384&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Office Max - Home Depot&lt;/div&gt;`)[0];
#                 popup_d3fb7f635264c00c8b9b65042947f2c8.setContent(html_8802a22f68f48fee4dd0fc5c4b22d384);
#
#
#
#         marker_f2afa696ed43b269299c52b40d59bd52.bindPopup(popup_d3fb7f635264c00c8b9b65042947f2c8)
#         ;
#
#
#
#
#             var marker_3cc6d1dbd86bd6085e2e34e303165f6d = L.marker(
#                 [34.2924134, -118.4497914],
#                 {}
#             ).addTo(map_664d0cc323930b4213b42ba32cf1780d);
#
#
#         var popup_7412f9c5277b1e7c048aa6f95426f529 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6e904844c3f50ba1206ad034ca1b665 = $(`&lt;div id=&quot;html_d6e904844c3f50ba1206ad034ca1b665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sylmar Metrolink Station&lt;/div&gt;`)[0];
#                 popup_7412f9c5277b1e7c048aa6f95426f529.setContent(html_d6e904844c3f50ba1206ad034ca1b665);
#
#
#
#         marker_3cc6d1dbd86bd6085e2e34e303165f6d.bindPopup(popup_7412f9c5277b1e7c048aa6f95426f529)
#         ;
#
#
#
#
#             var marker_a82847f0dbe6d685072a2af8f7fe41b5 = L.marker(
#                 [34.145528, -118.050548],

# %%
#load gas prices csv
gas_prices_to_load = Path("Resources/gas_prices.csv")

# %%
#read csv and change index
gas_prices = pd.read_csv(gas_prices_to_load)
gas_prices.set_index('Year')
# Out:
#         Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# Year
# 2000  1.301  1.369  1.541  1.506  1.498  1.617  1.593  1.510  1.582  1.559
# 2001  1.472  1.484  1.447  1.564  1.729  1.640  1.482  1.427  1.531  1.362
# 2002  1.139  1.130  1.241  1.407  1.421  1.404  1.412  1.423  1.422  1.449
# 2003  1.473  1.641  1.748  1.659  1.542  1.514  1.524  1.628  1.728  1.603
# 2004  1.592  1.672  1.766  1.833  2.009  2.041  1.939  1.898  1.891  2.029
# 2005  1.823  1.918  2.065  2.283  2.216  2.176  2.316  2.506  2.927  2.785
# 2006  2.315  2.310  2.401  2.757  2.947  2.917  2.999  2.985  2.589  2.272
# 2007  2.274  2.285  2.592  2.860  3.130  3.052  2.961  2.782  2.789  2.793
# 2008  3.047  3.033  3.258  3.441  3.764  4.065  4.090  3.786  3.698  3.173
# 2009  1.787  1.928  1.949  2.056  2.265  2.631  2.543  2.627  2.574  2.561
# 2010  2.731  2.659  2.780  2.858  2.869  2.736  2.736  2.745  2.704  2.795
# 2011  3.091  3.167  3.546  3.816  3.933  3.702  3.654  3.630  3.612  3.468
# 2012  3.399  3.572  3.868  3.927  3.792  3.552  3.451  3.707  3.856  3.786
# 2013  3.351  3.693  3.735  3.590  3.623  3.633  3.628  3.600  3.556  3.375
# 2014  3.320  3.364  3.532  3.659  3.691  3.695  3.633  3.481  3.403  3.182
# 2015  2.110  2.249  2.483  2.485  2.775  2.832  2.832  2.679  2.394  2.289
# 2016  1.967  1.767  1.958  2.134  2.264  2.363  2.225  2.155  2.208  2.243
# 2017  2.351  2.299  2.323  2.418  2.386  2.337  2.281  2.374  2.630  2.484
# 2018  2.539  2.575  2.572  2.737  2.907  2.914  2.873  2.862  2.873  2.887
# 2019  2.289  2.353  2.564  2.835  2.901  2.752  2.776  2.655  2.630  2.673
# 2020  2.567  2.465  2.267  1.876  1.879  2.076  2.176  2.177  2.193  2.159
# 2021  2.326  2.496  2.791  2.839  2.972  3.154  3.233  3.255  3.265  3.385
# 2022  3.413  3.592  4.312  4.271  4.604  5.058  4.667  4.101  3.881  4.016
# 2023  3.452  3.514  3.551  3.735  3.685  3.712  3.732  3.955  3.988  3.782
# 2024  3.221  3.359    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#         Nov    Dec
# Year
# 2000  1.555  1.489
# 2001  1.263  1.131
# 2002  1.448  1.394
# 2003  1.535  1.494
# 2004  2.010  1.882
# 2005  2.343  2.186
# 2006  2.241  2.334
# 2007  3.069  3.020
# 2008  2.151  1.689
# 2009  2.660  2.621
# 2010  2.852  2.985
# 2011  3.423  3.278
# 2012  3.488  3.331
# 2013  3.251  3.277
# 2014  2.887  2.560
# 2015  2.185  2.060
# 2016  2.187  2.230
# 2017  2.548  2.459
# 2018  2.671  2.414
# 2019  2.620  2.587
# 2020  2.090  2.168
# 2021  3.482  3.408
# 2022  3.853  3.356
# 2023  3.500  3.289
# 2024    NaN    NaN

# %%
#plot gas prices over the years and save fig
gas_prices.plot(x='Year')
plt.ylabel("Gas Prices($)")
plt.title("Monthly changes in gas prices since 2000")
plt.show()
plt.savefig('Images/gas_prices.png')

# %%
#load ev_sales csv 
ev_sales_to_load = Path("Resources/ev_historical_sales.csv")

# %%
#read csv
ev_sales = pd.read_csv(ev_sales_to_load)

# %%
#show only columns of interest
ev_sales_cleaned = ev_sales[["region", "powertrain","year", "value"]]

# %%
#save cleaned csv
ev_sales_cleaned.to_csv("Cleaned_data/ev_sales.csv", index=False)

# %%
#set index and clean to show only results for USA
historical_ev_final = ev_sales_cleaned.loc[(ev_sales_cleaned['region'] == 'USA')].set_index('year')
historical_ev_final

# %%
#plot and save fig
historical_ev_final.groupby('powertrain')['value'].plot(legend="true")
plt.ylabel('Number of cars sold')
plt.title('BEV vs PHEV cars sold in the USA from 2010 to 2022')
plt.show()
plt.savefig('Images/ev_sales.png')

# %%
#load csv
sales_compared_to_load = Path("Resources/car_sales_compared.csv")

# %%
#read_csv
all_sales = pd.read_csv(sales_compared_to_load)

# %%
#
all_sales_final= all_sales.loc[(all_sales['Entity'] == 'United States')]
all_sales_final

# %%
all_sales_final.to_csv('Cleaned_data/all_sales_final.csv', index=False)

# %%
plt.plot(all_sales_final['Year'], all_sales_final['Electric cars sold'], label = 'Electric cars sold')
plt.plot(all_sales_final['Year'], all_sales_final['Non-electric car sales'], label = 'Non-electric cars sold')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Number of cars sold')
plt.title('Car sales in the United States from 2011-2022')
ax= plt.gca()
ax.get_xaxis().get_major_formatter().set_scientific(False)
ax.get_yaxis().get_major_formatter().set_scientific(False)
plt.show()
plt.savefig('Images/all_car_sales.png')
