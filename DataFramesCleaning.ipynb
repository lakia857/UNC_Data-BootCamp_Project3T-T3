# %%
import pandas as pd
from pathlib import Path

# %%
ev_stations_to_load = Path("Resources/ev_stations_v1.csv")

# %%
ev_stations = pd.read_csv(ev_stations_to_load)
# Out:
# /var/folders/0h/lqy3k6gn3dnf1vwn1ct91kc80000gn/T/ipykernel_25223/3517020944.py:1: DtypeWarning: Columns (6,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_stations = pd.read_csv(ev_stations_to_load)

# %%
ev_stations.head()
# Out:
#   Fuel Type Code                     Station Name         Street Address  \
# 0           ELEC         LADWP - Truesdale Center     11797 Truesdale St
# 1           ELEC  LADWP - West LA District Office  1394 S Sepulveda Blvd
# 2           ELEC    Los Angeles Convention Center     1201 S Figueroa St
# 3           ELEC    LADWP - John Ferraro Building          111 N Hope St
# 4           ELEC       LADWP - Haynes Power Plant          6801 E 2nd St
#
#     Intersection Directions         City State    ZIP  Plus4 Station Phone  \
# 0                       NaN   Sun Valley    CA  91352    NaN           NaN
# 1                       NaN  Los Angeles    CA  90024    NaN           NaN
# 2  West hall and South hall  Los Angeles    CA  90015    NaN  213-741-1151
# 3               Across Hope  Los Angeles    CA  90012    NaN           NaN
# 4                       NaN   Long Beach    CA  90803    NaN           NaN
#
# ...

# %%
cleaned_df = ev_stations[["Station Name", "Street Address", "City", "State",
                         "ZIP", "Groups With Access Code", "Access Days Time", 
                         "Latitude", "Longitude", "EV Pricing"]]
cleaned_df
# Out:
#                             Station Name                    Street Address  \
# 0               LADWP - Truesdale Center                11797 Truesdale St
# 1        LADWP - West LA District Office             1394 S Sepulveda Blvd
# 2          Los Angeles Convention Center                1201 S Figueroa St
# 3          LADWP - John Ferraro Building                     111 N Hope St
# 4             LADWP - Haynes Power Plant                     6801 E 2nd St
# ...                                  ...                               ...
# 50284                   VIP LOT STATION1          1501 Kirkwood Meadows Dr
# 50285          Prunedale Shopping Center         8065 San Miguel Canyon Rd
# 50286          Beaverton Electric Avenue  11665 SW Beaverton Hillsdale Hwy
# 50287                      Shell - Inman                  2040 Highway 292
# 50288  Westfield Trumbull (Trumbull, CT)                  5065 Main Street
#
#                City State    ZIP Groups With Access Code  \
# ...

# %%
cleaned_df.dropna(how='any')
# Out:
#                                  Station Name  \
# 10             California Air Resources Board
# 12                     Scripps Green Hospital
# 13                              Galpin Motors
# 14                          Galleria at Tyler
# 15     City of Pasadena - Holly Street Garage
# ...                                       ...
# 50237                        Bill Clough Ford
# 50238        Ford - Jerseyville Motor Company
# 50239                One/Two Irvington Center
# 50240                   600 New Hampshire Ave
# 50241                        Sonesta San Jose
#
#                            Street Address         City State    ZIP  \
# 10                       9530 Telstar Ave     El Monte    CA  91731
# 12                10666 N Torrey Pines Rd     La Jolla    CA  92037
# 13                      15421 Roscoe Blvd    Sepulveda    CA  91343
# 14                 1299 Galleria at Tyler    Riverside    CA  92503
# ...

# %%
cleaned_df.to_csv('cleaned_ev_stations.csv', index=False)

# %%
gas_prices_to_load = Path("Resources/gas_prices.csv")

# %%
gas_prices = pd.read_csv(gas_prices_to_load)

# %%
gas_prices
# Out:
#     Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 0   2000  1.301  1.369  1.541  1.506  1.498  1.617  1.593  1.510  1.582
# 1   2001  1.472  1.484  1.447  1.564  1.729  1.640  1.482  1.427  1.531
# 2   2002  1.139  1.130  1.241  1.407  1.421  1.404  1.412  1.423  1.422
# 3   2003  1.473  1.641  1.748  1.659  1.542  1.514  1.524  1.628  1.728
# 4   2004  1.592  1.672  1.766  1.833  2.009  2.041  1.939  1.898  1.891
# 5   2005  1.823  1.918  2.065  2.283  2.216  2.176  2.316  2.506  2.927
# 6   2006  2.315  2.310  2.401  2.757  2.947  2.917  2.999  2.985  2.589
# 7   2007  2.274  2.285  2.592  2.860  3.130  3.052  2.961  2.782  2.789
# 8   2008  3.047  3.033  3.258  3.441  3.764  4.065  4.090  3.786  3.698
# 9   2009  1.787  1.928  1.949  2.056  2.265  2.631  2.543  2.627  2.574
# 10  2010  2.731  2.659  2.780  2.858  2.869  2.736  2.736  2.745  2.704
# 11  2011  3.091  3.167  3.546  3.816  3.933  3.702  3.654  3.630  3.612
# ...

# %%
gas_prices.to_csv('gas_prices_df.csv', index=False)

# %%
light_duty_vehicle_inventory_to_load = Path("Resources/citylightdutyvehicleinventory.csv")

# %%
light_duty_vehicle_inventory = pd.read_csv(light_duty_vehicle_inventory_to_load)

# %%
light_duty_vehicle_inventory.dropna(how='any')
# Out:
#        state_abbr    gisjoin  city_id       city_name fuel_type_org  \
# 576            AL  G01007000   107000      Birmingham           UNK
# 2868           AL  G01037000   137000      Huntsville           UNK
# 3710           AL  G01050000   150000          Mobile           UNK
# 3755           AL  G01051000   151000      Montgomery           UNK
# 3855           AL  G01051696   151696  Mountain Brook           UNK
# ...           ...        ...      ...             ...           ...
# 288834         VA  G51057000  5157000         Norfolk           UNK
# 289664         VA  G51082000  5182000  Virginia Beach           UNK
# 293210         WA  G53067000  5367000         Spokane           UNK
# 302297         WI  G55051150  5551150          Mequon           UNK
# 302462         WI  G55053000  5553000       Milwaukee           UNK
#
#             fuel_type    class before 1980 1980-99 1990-99  ... 2009.1 2010.1  \
# ...

# %%
ev_sales_to_load = Path("Resources/ev_historical_sales.csv")

# %%
ev_sales = pd.read_csv(ev_sales_to_load)

# %%
ev_sales
# Out:
#         region    category parameter  mode powertrain  year      unit    value
# 0    Australia  Historical  EV sales  Cars        BEV  2011  Vehicles       49
# 1    Australia  Historical  EV sales  Cars        BEV  2012  Vehicles      170
# 2    Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles       80
# 3    Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles      100
# 4    Australia  Historical  EV sales  Cars        BEV  2013  Vehicles      190
# ..         ...         ...       ...   ...        ...   ...       ...      ...
# 829      World  Historical  EV sales  Cars       PHEV  2020  Vehicles   970000
# 830      World  Historical  EV sales  Cars       PHEV  2021  Vehicles  1900000
# 831      World  Historical  EV sales  Cars        BEV  2021  Vehicles  4600000
# 832      World  Historical  EV sales  Cars        BEV  2022  Vehicles  7300000
# 833      World  Historical  EV sales  Cars       PHEV  2022  Vehicles  2900000
#
# [834 rows x 8 columns]

# %%
ev_sales_cleaned = ev_sales[["region", "powertrain","year", "value"]]
ev_sales_cleaned
# Out:
#         region powertrain  year    value
# 0    Australia        BEV  2011       49
# 1    Australia        BEV  2012      170
# 2    Australia       PHEV  2012       80
# 3    Australia       PHEV  2013      100
# 4    Australia        BEV  2013      190
# ..         ...        ...   ...      ...
# 829      World       PHEV  2020   970000
# 830      World       PHEV  2021  1900000
# 831      World        BEV  2021  4600000
# 832      World        BEV  2022  7300000
# 833      World       PHEV  2022  2900000
#
# [834 rows x 4 columns]

# %%
ev_sales_cleaned.to_csv("Cleaned_data/ev_sales.csv", index=False)
